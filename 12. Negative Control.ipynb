# %%
import pandas as pd
import numpy
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
def df_gdomain_counter(df):
    """
    function to count the no. of G-Domains per protein family
    """
    df_count = df["ProteinID"].value_counts()

    return df_count

# %%
# all G boxes
def match(x, y, mm):
    mismatch = 0
    for i in range(len(x)):
        if (x[i] == 'X' or x[i] == y[i]):
            pass
        else:
            mismatch += 1
    if (mismatch <= mm):
        return True
    else:
        return False

# %%
def H(protein_id, protein, x1, x2, x3, x4, mm1, mm2, mm3, mm4, min13, min34, min45, max13, max34, max45):
    pL1 = []
    pL2 = []
    pL3 = []
    pL4 = []
    L1 = []
    L2 = []
    L3 = []
    L4 = []
    for i in range(len(protein) - len(x1)):
        if (match(x1, protein[i:i + len(x1)], mm1) == True):
            #                       global L1
            pL1 = pL1 + [i]
            L1 = L1 + [protein[i:i + len(x1)]]
    # print "L1 = ", pL1,L1
    for j in range(len(protein) - len(x2)):
        if (match(x2, protein[j:j + len(x2)], mm2) == True):
            #                       global L2
            pL2 = pL2 + [j]
            L2 = L2 + [protein[j:j + len(x2)]]
    # print "L2 = ", pL2,L2
    for k in range(len(protein) - len(x3)):
        if (match(x3, protein[k:k + len(x3)], mm3) == True):
            #                       global L3
            pL3 = pL3 + [k]
            L3 = L3 + [protein[k:k + len(x3)]]
    # print "L3 = ", pL3,L3
    for l in range(len(protein) - len(x4)):
        if (match(x4, protein[l:l + len(x4)], mm4) == True):
            #                       global L3
            pL4 = pL4 + [l]
            L4 = L4 + [protein[l:l + len(x4)]]
    candidates = []
    for i in range(len(pL1)):
        for j in range(len(pL2)):
            for k in range(len(pL3)):
                for l in range(len(pL4)):
                    if (min13 <= pL2[j] - pL1[i] <= max13 and min34 <= pL3[k] - pL2[j] <= max34 and min45 <= pL4[l] -
                            pL3[k] <= max45):
                        # if 80 <=pL2[j]-pL1[i]  <= 120 and 40 <=pL3[k]- pL2[j] <= 80 and 20 <=pL4[l]- pL3[k] <= 80
                        a = L1[i]
                        a_pos = pL1[i]
                        b = L2[j]
                        b_pos = pL2[j]
                        c = L3[k]
                        c_pos = pL3[k]
                        d = L4[l]
                        d_pos = pL4[l]

                        print(protein_id, a, a_pos, b, b_pos, c, c_pos, d, d_pos)
                        candidates.append((protein_id, a, a_pos, b, b_pos, c, c_pos, d, d_pos))

    return candidates

# %%
def shuffler(word):
    word_to_scramble = list(word)
    numpy.random.shuffle(word_to_scramble)
    # O=seq= ''.join(seq_temp)
    new_word = ''.join(word_to_scramble)
    return new_word

# %%
sheet_path = "/content/drive/My Drive/Colab Notebooks/GProtein_Project/sheet.csv"
data = pd.read_csv(sheet_path)

# %%
data.head()
# Out:
#   Protein  ...                                            Thr_out
# 0     Rab  ...  /content/drive/My Drive/Colab Notebooks/GProte...
# 1     Rac  ...  /content/drive/My Drive/Colab Notebooks/GProte...
# 2     Ran  ...  /content/drive/My Drive/Colab Notebooks/GProte...
# 3     Ras  ...  /content/drive/My Drive/Colab Notebooks/GProte...
# 4     Roc  ...  /content/drive/My Drive/Colab Notebooks/GProte...
#
# [5 rows x 29 columns]

# %%
family = input("Enter Protein Family: ")
print(family)
# Out:
# Enter Protein Family: Era
# Era

# %%
counter = {}

# %%
for x in range(27):
    protein_family = data.loc[x, "Protein"]
    print(protein_family)
    if family == protein_family:
        print(protein_family)
        inpath = data.loc[x, "in_path_new"]
        inpath_before = data.loc[x, "out_path_new"]
        outpath = data.loc[x, "Negative_Control"]

        mismatch1 = data.loc[x, "Mismatch_G1"]
        mismatch2 = data.loc[x, "Mismatch_G3"]
        mismatch3 = data.loc[x, "Mismatch_G4"]
        mismatch4 = data.loc[x, "Mismatch_G5"]
        print(mismatch1, mismatch2, mismatch3, mismatch4)

        x1 = data.loc[x, "G1_box"]
        x2 = data.loc[x, "G3_box"]
        x3 = data.loc[x, "G4_box"]
        x4 = data.loc[x, "G5_box_new"]
        print(x1, x2, x3, x4)

        Min_G1_G3 = data.loc[x, "Min_G1_G3"]
        Max_G1_G3 = data.loc[x, "Max_G1_G3"]
        Min_G3_G4 = data.loc[x, "Min_G3_G4"]
        Max_G3_G4 = data.loc[x, "Max_G3_G4"]
        Min_G4_G5 = data.loc[x, "Min_G4_G5"]
        Max_G4_G5 = data.loc[x, "Max_G4_G5"]

        df1 = pd.read_excel(inpath)
        df2 = df1.set_index("Entry", drop=False)
        protein = df2.loc[:, "Sequence"]
        protein_id = df2.loc[:, "Entry"]
        protein_id

        for j in range(50):
            abc = []
            l1 = []
            for i in range(len(protein)):
                s = shuffler(protein[i])
                l = H(protein_id[i], s, x1, x2, x3, x4, mismatch1, mismatch2, mismatch3, mismatch4, Min_G1_G3,
                      Min_G3_G4, Min_G4_G5, Max_G1_G3, Max_G3_G4, Max_G4_G5)
                l1.append(l)
                abc = [item for sublist in l1 for item in sublist]
            # f = open(out_csv[clas],'a')
            gdomains = pd.DataFrame(abc, columns=['ProteinID', 'G1-box', 'Position', 'G3-box', 'Position', 'G4-box',
                                                  'Position', 'G5-box', 'Position'])
            counter[j] = df_gdomain_counter(gdomains)
# Out:
# Rab
# Rac
# Ran
# Ras
# Roc
# Arf
# AIG1
# Era
# Era
# 1 1 1 1
# GXXXXGK DXXG NKXD PXSAX
# B9KGA1 GLKSNGN 140 DIKE 183 YKLD 252 KVSAE 283
# B9KGA1 GLKSNGN 140 DILI 190 YKLD 252 KVSAE 283
# B9KGA1 GNETTRK 145 DILI 190 YKLD 252 KVSAE 283
# A1UIQ1 GRSRVGI 58 EPKG 105 RKHD 172 PRSIE 203
# A1UIQ1 GRSRVGI 58 GKQG 108 RKHD 172 PRSIE 203
# Q8JIF5 GEGGVGD 34 DRVT 82 PKAD 152 LVSAE 177
# Q5SM23 GGVVDLK 141 AHPG 187 MKFD 249 HVSAN 284
# C6E2H7 GTDGFGV 48 NFDG 95 GKDD 159 FISAL 192
# C6E2H7 GTDGFGV 48 DGEV 97 GKDD 159 FISAL 192
# C6E2H7 GTDGFGV 48 GEVG 98 GKDD 159 FISAL 192
# B9MS56 SFVMSGK 74 EEEG 117 NKII 185 PNKAL 213
# Q0TNU5 GIGMLTK 92 QLDG 141 NKVP 209 TRSAS 244
# Q8JIF5 GGMDDGA 41 DKLS 83 NKVY 146 PASLG 175
# Q5FJT7 GGEQDGR 84 IGKG 132 KKLD 202 PYSKF 230
# Q9RWM0 GPQVPGQ 123 DPAP 163 TKKD 230 PFAAS 262
# Q9RWM0 GPQVPGQ 123 ENLG 168 TKKD 230 PFAAS 262
# A1JKK4 TERKKGK 63 DEMN 106 NGLD 172 PESHV 199
# A1JKK4 TERKKGK 63 DKVV 112 NGLD 172 PESHV 199
# B9MS56 GTPKNVK 43 KIGG 91 NKSA 161 RSSAG 187
# B8DQN1 GQPKTIK 4 DEKG 46 SKVD 116 PLVAK 143
# Q8RB50 GIVALEK 57 DEKI 100 KKFD 169 LSSAP 198
# Q8RB50 GIVALEK 57 DEKI 100 KKFD 169 PYSGG 202
# Q8RB50 GIVALEK 57 KIFG 102 KKFD 169 LSSAP 198
# Q8RB50 GIVALEK 57 KIFG 102 KKFD 169 PYSGG 202
# C1CDW4 GHKSYQK 133 DNVA 177 NKDT 242 PVSVD 271
# C1CDW4 GHKSYQK 133 TPFG 181 NKDT 242 PVSVD 271
# Q0SMJ3 GFFSTGK 6 NGLG 48 NGID 117 PSSEK 150
# Q0SMJ3 GFFSTGK 6 DEVK 55 NGID 117 PSSEK 150
# A5IXQ6 ELVPDGK 70 DKKE 112 IKTD 178 PVKAK 209
# B5X2B8 RIKAFGK 126 DFQV 174 LKCD 244 QESAG 270
# B5X2B8 RIKAFGK 126 FQVG 175 LKCD 244 QESAG 270
# Q182C3 IEDDVGK 56 DFLE 97 NKLL 159 PSIAV 188
# A5PK43 GAGHLGC 250 AQVG 296 NKSD 362 PVSYK 394
# B1HTJ0 GQEVTVK 55 DEID 97 QKPD 164 EHSAD 189
# B1HTJ0 GQEVTVK 55 IDMG 99 QKPD 164 EHSAD 189
# B1HTJ0 GQEVTVK 55 DMGV 100 QKPD 164 EHSAD 189
# B1HTJ0 GQEVTVK 55 MGVG 101 QKPD 164 EHSAD 189
# B2KB94 GENLEGA 22 DWRH 67 NKFK 127 PQSVG 158
# B9MS56 GVSFKGT 148 DMDW 192 QKID 256 PGSWE 287
# B9MS56 GVSFKGT 148 DWLL 194 QKID 256 PGSWE 287
# B9MS56 GVSFKGT 148 WLLG 195 QKID 256 PGSWE 287
# B0USS2 GTAQGIK 149 RANG 190 TKSD 255 ITSAR 282
# B0USS2 GTAQGIK 149 GVEG 193 TKSD 255 ITSAR 282
# Q98QI1 GSTNQGT 87 LEKG 129 NYVD 198 NPSAQ 228
# Q98QI1 GTKNDSK 92 DDLL 138 NYVD 198 NPSAQ 228
# A6LL68 FRDLWGK 140 DKPT 189 NKLK 256 GESAP 281
# Q92R46 EYARCGK 129 DAVK 174 RKLD 236 PRNAH 264
# Q8PMU9 GASTKGG 0 DSVD 46 NKEL 113 AVSAV 138
# Q8PMU9 GASTKGG 0 DSLV 49 NKEL 113 AVSAV 138
# Q8PMU9 ASTKGGK 1 DSVD 46 NKEL 113 AVSAV 138
# Q8PMU9 ASTKGGK 1 DSLV 49 NKEL 113 AVSAV 138
# Q8VZ74 PDDEKGK 69 DKME 115 NSKD 183 GESAE 216
# Q8VZ74 PDDEKGK 69 KMEG 116 NSKD 183 GESAE 216
# B8I736 SEGEPGK 78 ISTG 122 NKIL 191 PYSTT 223
# B8I736 GEPGKLK 80 ISTG 122 NKIL 191 PYSTT 223
# Q97JI5 LVVSRGK 125 IDAG 173 TKAD 239 PGSAK 268
# Q97JI5 LVVSRGK 125 DAGE 174 TKAD 239 PGSAK 268
# A0Q1Q0 GLVDVKK 46 DPLI 93 NKFV 158 PGTAV 188
# C1CXC1 ASLDLGK 101 DQAD 148 NKTT 217 PWYAV 246
# C1CXC1 ASLDLGK 101 DEEK 151 NKTT 217 PWYAV 246
# A7GYN7 GSDQDGK 86 VYMG 129 NKVD 195 PQQAM 225
# B8J3P9 GLHIHAK 141 KWPG 185 NKAR 254 HDSAQ 286
# B8F3C8 GRNNDAK 41 VSEG 91 NKDG 160 PRAAV 186
# B5XNH1 DKRKIGK 126 FTTG 171 NGVD 231 EKSAN 258
# Q82SJ6 AERFTGK 84 DNFT 128 NIYD 192 AISAL 218
# Q7VW40 GAQFKHK 79 YGEG 124 EKSD 193 ELSAT 221
# Q8YG75 EVIVEGK 8 DLET 48 NKKV 114 PEEAG 149
# Q8YG75 EVIVEGK 8 VENG 53 NKKV 114 PEEAG 149
# B2S103 AKLRKGK 121 DAIH 165 NKQI 232 SISAG 266
# B8CXI2 GAMSLGF 47 DFAK 88 QKVD 158 PESEG 192
# B8CXI2 GAMSLGF 47 PEVG 93 QKVD 158 PESEG 192
# B0TAF1 KSTLAGK 137 IIVG 185 NKPI 254 STSAI 282
# Q1RHA4 GFLLEGI 56 DNSL 96 YKFD 163 TFSAE 196
# Q1RHA4 GFLLEGI 56 DSVD 100 YKFD 163 TFSAE 196
# Q1RHA4 GFLLEGI 56 DINI 103 YKFD 163 TFSAE 196
# Q1RHA4 GIFQVTK 61 DINI 103 YKFD 163 TFSAE 196
# B3WEL1 GMTAANK 163 LLEG 206 NKLE 267 DQSAA 293
# Q89AM7 GIIKVDK 51 DKHT 91 NKAF 161 PSIAQ 191
# Q8JIF5 GKRVPGG 238 TSKG 285 TKQD 353 VYSAK 386
# Q8JIF5 RTNNRGK 251 AKIG 291 TKQD 353 VYSAK 386
# Q03F63 GIPQQRK 23 PQAG 64 LKLD 131 PQSIN 162
# Q03F63 GIPQQRK 23 DPNT 69 LKLD 131 PQSIN 162
# O82653 GSGEKEK 133 FTEG 180 PKQD 241 LDSAK 267
# Q9RDF2 GEHPWGD 27 VAKG 71 NKKF 136 PPGAQ 169
# C6E2H7 GLPDKGI 132 FRDG 179 LKID 241 LKSAE 274
# C6E2H7 GLPDKGI 132 DGVF 181 LKID 241 LKSAE 274
# B6JL99 LNNNLGK 132 DIEP 174 AKCD 234 PALAF 265
# Q5WHD9 LYREGGK 79 DSQF 125 LKKD 190 LQSAQ 222
# FeoB
# Hflx
# Hflx
# GB1
# EngB
# EngB
# Dynamin
# Dynamin
# IRG
# Obg
# Obg
# Septin
# SRP
# Translational
# Translational
# Translational
# Translational
# tRme
# EngA

# %%
xyz = pd.DataFrame(pd.concat(counter.values()))
xyz['Protein'] = xyz.index
xyz_mean_after = xyz.groupby(['Protein']).sum() / 50
xyz_mean_after['Protein'] = xyz_mean_after.index

# %%
xyz_mean_after.head()
# Out:
#          ProteinID Protein
# Protein
# A0Q1Q0        0.02  A0Q1Q0
# A0RPN6        0.02  A0RPN6
# A1APR8        0.04  A1APR8
# A1JKK4        0.06  A1JKK4
# A1R085        0.06  A1R085

# %%
xyz_mean_after.to_csv('/content/drive/My Drive/Colab Notebooks/negcontrol.csv')

# %%
xyz_before = pd.read_csv(inpath_before)
xyz_before = pd.DataFrame(df_gdomain_counter(xyz_before))
xyz_before['Protein'] = xyz_before.index

# %%
xyz_before.head()
# Out:
#         ProteinID Protein
# Q9RWM0          4  Q9RWM0
# B7IH25          4  B7IH25
# B3ETC6          4  B3ETC6
# Q9K0C7          3  Q9K0C7
# A6LL68          3  A6LL68

# %%
xyz_before.to_csv('/content/drive/My Drive/Colab Notebooks/before.csv')
