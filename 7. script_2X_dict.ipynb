# %%
# !pip install pandas
# !pip install python-Levenshtein
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (0.25.3)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from pandas) (1.17.4)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas) (2.6.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas) (1.12.0)
# Collecting python-Levenshtein
#   Downloading https://files.pythonhosted.org/packages/42/a9/d1785c85ebf9b7dfacd08938dd028209c34a0ea3b1bcdb895208bd40a67d/python-Levenshtein-0.12.0.tar.gz (48kB)
#      |████████████████████████████████| 51kB 1.7MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from python-Levenshtein) (42.0.2)
# Building wheels for collected packages: python-Levenshtein
#   Building wheel for python-Levenshtein (setup.py) ... done
#   Created wheel for python-Levenshtein: filename=python_Levenshtein-0.12.0-cp36-cp36m-linux_x86_64.whl size=144668 sha256=2ed56c80dac3edda1391b81d6a6a0ef5d16b937f756570db5d509489eb492556
#   Stored in directory: /root/.cache/pip/wheels/de/c2/93/660fd5f7559049268ad2dc6d81c4e39e9e36518766eaf7e342
# Successfully built python-Levenshtein
# Installing collected packages: python-Levenshtein
# Successfully installed python-Levenshtein-0.12.0

# %%
#import required libraries
import pandas as pd
import Levenshtein
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# funtion to get all the possible 7mers with one 2X in it.

# %%
def list_of_7mer_2X(sevenmer):
    x_data = []
    for r1 in range(7):
        for r2 in range(7):
            if (r1!=r2):
                x=list(sevenmer)
                x[r1]="X"
                x[r2]="X"
                x= ''.join(x)
                x_data.append(x)
    return x_data

# %% [markdown]
# Enter path to the 7mer master sheet which contains paths for input and output.

# %%
sheet_path= "/content/drive/My Drive/Colab Notebooks/GProtein_Project/7mer_sheet.csv"
data_sheet = pd.read_csv(sheet_path)

# %% [markdown]
# Enter the name of the family you for which you want to introduce 2X in the G5-Box 7mers.

# %%
family = input("Enter Protein Family: ")
print (family)
# Out:
# Enter Protein Family: Ras
# Ras

# %% [markdown]
# Insert 2X at all possible positions in G5-Box from 'SA' with 1 mismatch G-Domains

# %%
for x in range(20):
    protein_family = data_sheet.loc[x , "Protein_Class"]
    print (protein_family)
    if (family==protein_family):
        print (protein_family)
        inpath_SA_mm= data_sheet.loc[x , "Inpath_SA_mm"]
        outpath1_SA_mm= data_sheet.loc[x , "Outpath_2X_SA_mm"]
        outpath2_SA_mm= data_sheet.loc[x , "Outpath_2X_SA_mm_count"]

        total= data_sheet.loc[x , "Count"]

        data = pd.read_csv(inpath_SA_mm)

        unique_7mers= data['G5-box'].unique()
        temp= data

        id_set = {}

        for j in range(temp.shape[0]):
            seq= temp.loc[j,"G5-box"]
            ID= temp.loc[j,"ProteinID"]
            
            x_data = list_of_7mer_2X(seq)
            for x in x_data:
                if(x not in id_set):
                    id_set[x] = set()
                    id_set[x].add(ID)
                else:
                    id_set[x].add(ID)

# %%
id_set.items()

# %% [markdown]
# Write the results to the drive.

# %%
with open(outpath1_SA_mm, 'w') as f:   
    [f.write('{0},{1}\n'.format(key, value)) for key, value in id_set.items()]

with open(outpath2_SA_mm, 'w') as f:
    [f.write('{0},{1}\n'.format(key, [len(value),round((100 * len(value) / total),2)])) for key, value in id_set.items()]

# %% [markdown]
# Insert 2X at all possible positions in G5-Box from 'A' with no mismatch G-Domains

# %%
for x in range(20):
    protein_family = data_sheet.loc[x , "Protein_Class"]
    print (protein_family)
    if (family==protein_family):
        print (protein_family)
        inpath_A_nomm= data_sheet.loc[x , "Inpath_A_nomm"]
        outpath1_A_nomm= data_sheet.loc[x , "Outpath_2X_A_nomm"]
        outpath2_A_nomm= data_sheet.loc[x , "Outpath_2X_A_nomm_count"]

        total= data_sheet.loc[x , "Count"]

        data = pd.read_csv(inpath_A_nomm)

        unique_7mers= data['G5-box'].unique()
        temp= data

        id_set1 = {}

        for j in range(temp.shape[0]):
            seq= temp.loc[j,"G5-box"]
            ID= temp.loc[j,"ProteinID"]
            
            x_data = list_of_7mer_2X(seq)
            for x in x_data:
                if(x not in id_set1):
                    id_set1[x] = set()
                    id_set1[x].add(ID)
                else:
                    id_set1[x].add(ID)

# %%
id_set1.items()
# Out:
# dict_items([('XXSAKTR', {'Q7Z444', 'Q9JIW9', 'P83831', 'Q5F352', 'P79800', 'P01117', 'Q5RD87', 'P08646', 'P01114', 'B4JFU8', 'Q295X7', 'Q9YH38', 'P08642', 'Q91806', 'Q5R4B8', 'P01116', 'O42277', 'Q5EFX7', 'P22981', 'P08644', 'B4GFJ8', 'P63320', 'Q05147', 'P11234', 'B4NJ72', 'P32883', 'P11233', 'Q7TN89', 'B3NZR4', 'B3M185', 'B4LY29', 'Q55CB8', 'P01113', 'P01111', 'P23175', 'B4PUP5', 'P63321', 'Q95ME4', 'Q04970', 'P48555', 'P36860', 'Q9YH09', 'P63322', 'P83832', 'Q55CB7', 'P12825', 'B4HKC7', 'P05774', 'Q2MJK3', 'P22124', 'P01115', 'P08556', 'Q07983'}), ('XTXAKTR', {'Q7Z444', 'Q9JIW9', 'P83831', 'Q5F352', 'P79800', 'P01117', 'Q5RD87', 'P08646', 'P01114', 'B4JFU8', 'Q295X7', 'Q9YH38', 'P08642', 'Q91806', 'Q5R4B8', 'P01116', 'O42277', 'Q5EFX7', 'P22981', 'P08644', 'B4GFJ8', 'P63320', 'Q05147', 'P11234', 'B4NJ72', 'P32883
TN89', 'B3NZR4', 'B3M185', 'B4LY29', 'P51539', 'P01113', 'P01111', 'P23175', 'B4PUP5', 'P63321', 'Q95ME4', 'Q04970', 'P48555', 'P36860', 'Q9YH09', 'P63322', 'P83832', 'P12825', 'B4HKC7', 'P05774', 'Q2MJK3', 'P22124', 'P01115', 'P08556', 'Q07983'}), ('EXXAKTR', {'Q7Z444', 'Q9JIW9', 'P83831', 'Q5F352', 'P79800', 'P01117', 'Q5RD87', 'P08646', 'P01114', 'B4JFU8', 'Q295X7', 'Q9YH38', 'P08642', 'Q91806', 'Q5R4B8', 'P01116', 'O42277', 'Q5EFX7', 'P08644', 'B4GFJ8', 'P63320', 'Q05147', 'P11234', 'B4NJ72', 'P32883', 'P11233', 'B3NZR4', 'B3M185', 'B4LY29', 'Q55CB8', 'P01111', 'P23175', 'B4PUP5', 'P63321', 'Q95ME4', 'Q04970', 'P48555', 'P36860', 'Q9YH09', 'P63322', 'P83832', 'Q55CB7', 'P12825', 'B4HKC7', 'P05774', 'Q2MJK3', 'P22124', 'P01115', 'P08556', 'Q07983'}), ('EXSXKTR', {'Q7Z444', 'Q9JIW9', 'P83831', 'Q5F352', 'P79800', 'P01117',  ...

# %% [markdown]
# Write the results to the drive.

# %%
with open(outpath1_A_nomm, 'w') as f:   
    [f.write('{0},{1}\n'.format(key, value)) for key, value in id_set1.items()]

with open(outpath2_A_nomm, 'w') as f:
    [f.write('{0},{1}\n'.format(key, [len(value),round((100 * len(value) / total),2)])) for key, value in id_set1.items()]

# %% [markdown]
# Insert 2X at all possible positions in G5-Box from 'SA' with no mismatch G-Domains

# %%
for x in range(20):
    protein_family = data_sheet.loc[x , "Protein_Class"]
    print (protein_family)
    if (family==protein_family):
        print (protein_family)
        inpath_SA_nomm= data_sheet.loc[x , "Inpath_SA_nomm"]
        outpath1_SA_nomm= data_sheet.loc[x , "Outpath_2X_SA_nomm"]
        outpath2_SA_nomm= data_sheet.loc[x , "Outpath_2X_SA_nomm_count"]

        total= data_sheet.loc[x , "Count"]

        data = pd.read_csv(inpath_SA_nomm)

        unique_7mers= data['G5-box'].unique()
        temp= data

        id_set2 = {}

        for j in range(temp.shape[0]):
            seq= temp.loc[j,"G5-box"]
            ID= temp.loc[j,"ProteinID"]
            
            x_data = list_of_7mer_2X(seq)
            for x in x_data:
                if(x not in id_set2):
                    id_set2[x] = set()
                    id_set2[x].add(ID)
                else:
                    id_set2[x].add(ID)
# Out:
# Rab
# Rac
# Ran
# Ras
# Ras
# Roc
# Arf
# AIG1
# Era
# FeoB
# Hflx
# GB1
# EngB
# Dynamin
# IRG
# Obg
# Septin
# SRP
# Translational
# tRme
# EngA

# %%
id_set2.items()

# %% [markdown]
# Write the results to the drive.

# %%
with open(outpath1_SA_nomm, 'w') as f:   
    [f.write('{0},{1}\n'.format(key, value)) for key, value in id_set2.items()]

with open(outpath2_SA_nomm, 'w') as f:
    [f.write('{0},{1}\n'.format(key, [len(value),round((100 * len(value) / total),2)])) for key, value in id_set2.items()]

# %% [markdown]
# Insert 2X at all possible positions in combined G5-Boxes from 'A' with no mismatch , 'SA' with no mismatch and 'SA' with one mismatch G-Domains

# %%
for x in range(20):
    protein_family = data_sheet.loc[x , "Protein_Class"]
    print (protein_family)
    if (family==protein_family):
        print (protein_family)
        inpath_SA_nomm= data_sheet.loc[x , "Inpath_SA_nomm"]
        inpath_SA_mm= data_sheet.loc[x , "Inpath_SA_mm"]
        inpath_A_nomm= data_sheet.loc[x , "Inpath_A_nomm"]
        
        outpath1 = data_sheet.loc[x , "Outpath_2X"]
        outpath2 = data_sheet.loc[x , "Outpath_2X_count"]


        SA_nomm= pd.read_csv(inpath_SA_nomm)
        A_nomm= pd.read_csv(inpath_A_nomm)
        SA_mm= pd.read_csv(inpath_SA_mm)

        table= [SA_nomm[['ProteinID', 'G5-box', 'Position']], A_nomm[['ProteinID', 'G5-box', 'Position']], SA_mm[['ProteinID', 'G5-box', 'Position']]]

        #table= [A_nomm[['Entry', 'G5_box', 'Value']], SA_mm[['Entry', 'G5_box', 'Value']]]


        data= pd.concat(table)
        data= data.reset_index(drop=True)
        
        unique_7mers= data['G5-box'].unique()
        temp= data

        id_set3 = {}

        for j in range(temp.shape[0]):
            seq= temp.loc[j,"G5-box"]
            ID= temp.loc[j,"ProteinID"]
            
            x_data = list_of_7mer_2X(seq)
            for x in x_data:
                if(x not in id_set3):
                    id_set3[x] = set()
                    id_set3[x].add(ID)
                else:
                    id_set3[x].add(ID)

# %%
id_set3.items()

# %% [markdown]
# Write the results to the drive.

# %%
with open(outpath1, 'w') as f:   
    [f.write('{0},{1}\n'.format(key, value)) for key, value in id_set3.items()]

with open(outpath2, 'w') as f:
    [f.write('{0},{1}\n'.format(key, [len(value),round((100 * len(value) / total),2)])) for key, value in id_set3.items()]
