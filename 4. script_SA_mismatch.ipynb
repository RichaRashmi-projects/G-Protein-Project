# %%
# !pip install pandas
# !pip install python-Levenshtein

# %%
#import required libraries
import pandas as pd
import Levenshtein
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# all G boxes
def match(x,y, mm):
        mismatch = 0
        for i in range(len(x)):
                if (x[i] == 'X' or x[i] == y[i]):
                        pass
                else:
                        mismatch += 1
        if(mismatch <= mm):
                return True
        else:
                return False

# %%
def H(protein_id, protein,x1,x2,x3,x4, mm1, mm2, mm3, mm4, min13, min34, min45, max13, max34, max45):
        pL1=[]
        pL2=[]
        pL3=[]
        pL4=[]
        L1=[]
        L2=[]
        L3=[]
        L4=[]
        for i in range(len(protein)-len(x1)):
                if(match(x1, protein[i:i+len(x1)],mm1) == True):
#                       global L1
                        pL1=pL1 + [i]
                        L1 = L1+[protein[i:i+len(x1)]]
        #print "L1 = ", pL1,L1
        for j in range(len(protein)-len(x2)):
                if (match(x2, protein[j:j+len(x2)],mm2) == True):
#                       global L2
                        pL2=pL2+[j]
                        L2 = L2+[protein[j:j+len(x2)]]
        #print "L2 = ", pL2,L2
        for k in range(len(protein)-len(x3)):
                if (match(x3, protein[k:k+len(x3)],mm3) == True):
#                       global L3
                        pL3=pL3+[k]
                        L3 = L3+[protein[k:k+len(x3)]]
        #print "L3 = ", pL3,L3
        for l in range(len(protein)-len(x4)):
                if (match(x4, protein[l:l+len(x4)],mm4) == True):
#                       global L3
                        pL4=pL4+[l]
                        L4 = L4+[protein[l:l+len(x4)]]
        candidates =[]                
        for i in range(len(pL1)):
                for j in range(len(pL2)):
                        for k in range(len(pL3)):
                                for l in range(len(pL4)):
                                     if (min13<= pL2[j]-pL1[i] <= max13 and min34 <=pL3[k]- pL2[j] <= max34 and min45 <=pL4[l]- pL3[k] <= max45) :
                        
                                        #if 80 <=pL2[j]-pL1[i]  <= 120 and 40 <=pL3[k]- pL2[j] <= 80 and 20 <=pL4[l]- pL3[k] <= 80
                                        a = L1[i]
                                        a_pos = pL1[i]
                                        b = L2[j]
                                        b_pos = pL2[j]
                                        c = L3[k]
                                        c_pos = pL3[k]
                                        d = L4[l]
                                        d_pos = pL4[l]
                                        
                                        print (protein_id, a, a_pos, b, b_pos,c, c_pos,d, d_pos)
                                        candidates.append((protein_id, a, a_pos, b, b_pos,c, c_pos,d, d_pos))
                                        

        return candidates

# %%
sheet_path= "/content/drive/My Drive/Colab Notebooks/GProtein_Project/sheet.csv"
data = pd.read_csv(sheet_path)

# %%
data.head()

# %%
family = input("Enter Protein Family: ")
print (family)
# Out:
# Enter Protein Family: Ras
# Ras

# %%
abc=[]
l1= []

for x in range(27):
    protein_family = data.loc[x , "Protein"]
    print (protein_family)
    if (family==protein_family):
        
        inpath= data.loc[x , "in_path_new"]
        outpath= data.loc[x , "SA_mismatch"]
        
        mismatch1= data.loc[x , "Mismatch_G1"]
        mismatch2= data.loc[x , "Mismatch_G3"]
        mismatch3= data.loc[x , "Mismatch_G4"]
        mismatch4= data.loc[x , "Mismatch_G5"]
        
        x1= data.loc[x , "G1_box"]
        x2= data.loc[x , "G3_box"]
        x3= data.loc[x , "G4_box"]
        x4= data.loc[x , "G5_box_SA"]
        
        Min_G1_G3= data.loc[x , "Min_G1_G3"]
        Max_G1_G3= data.loc[x , "Max_G1_G3"]
        Min_G3_G4= data.loc[x , "Min_G3_G4"]
        Max_G3_G4= data.loc[x , "Max_G3_G4"]
        Min_G4_G5= data.loc[x , "Min_G4_G5"]
        Max_G4_G5= data.loc[x , "Max_G4_G5"]
        
        df1 = pd.read_excel(inpath)
        df2 = df1.set_index("Entry", drop = False)
        protein = df2.loc[: , "Sequence"]
        protein_id = df2.loc[: , "Entry"]
        protein_id

      
        
        for i in range(len(protein)):
            l= H(protein_id[i], protein[i],x1,x2,x3,x4, mismatch1, mismatch2, mismatch3, mismatch4, Min_G1_G3, Min_G3_G4, Min_G4_G5, Max_G1_G3, Max_G3_G4, Max_G4_G5 )            
            l1.append(l)
            abc = [item for sublist in l1 for item in sublist]
            #f = open(out_csv[clas],'a')
# Out:
# Rab
# Rac
# Ran
# Ras
# P01116 GAGGVGK 9 DTAG 56 NKCD 115 IETSAKT 141
# P01116 GAGGVGK 9 DTAG 56 NKCD 115 RVEDAFY 150
# P32253 GDGGVGK 10 DTAG 57 NKAD 116 LETSAKS 144
# P32253 GDGGVGK 10 DTAG 57 NKAD 116 SAKSRVN 147
# P32883 GAGGVGK 9 DTAG 56 NKCD 115 IETSAKT 141
# P32883 GAGGVGK 9 DTAG 56 NKCD 115 RVEDAFY 150
# B4NJ72 GAGGVGK 9 DTAG 56 NKCD 115 IETSAKT 141
# B4NJ72 GAGGVGK 9 DTAG 56 NKCD 115 GVDDAFY 150
# Q8TAI7 GYRCVGK 12 DTAG 59 NKAD 118 FMESSAR 144
# Q8TAI7 GYRCVGK 12 DTAG 59 NKAD 118 MESSARE 145
# B4JFU8 GAGGVGK 9 DTAG 56 NKCD 115 IETSAKT 141
# B4JFU8 GAGGVGK 9 DTAG 56 NKCD 115 GVDDAFY 150
# P01120 GGGGVGK 16 DTAG 63 NKSD 122 LETSAKQ 149
# P01120 GGGGVGK 16 DTAG 63 NKSD 122 SAKQAIN 152
# Q80ZJ1 GSGGVGK 9 DTAG 56 NKVD 115 METSAKS 142
# Q80ZJ1 GSGGVGK 9 DTAG 56 NKVD 115 SAKSKTM 145
# P62835 GSGGVGK 9 DTAG 56 NKCD 115 FLESSAK 142
# P62835 GSGGVGK 9 DTAG 56 NKCD 115 LESSAKS 143
# P62835 GSGGVGK 9 DTAG 56 NKCD 115 SAKSKIN 146
# P11234 GSGGVGK 20 DTAG 67 NKSD 127 VETSAKT 154
# P11234 GSGGVGK 20 DTAG 67 NKSD 127 AKTRANV 158
# P62834 GSGGVGK 9 DTAG 56 NKCD 115 FLESSAK 142
# P62834 GSGGVGK 9 DTAG 56 NKCD 115 LESSAKS 143
# P62834 GSGGVGK 9 DTAG 56 NKCD 115 SAKSKIN 146
# P11233 GSGGVGK 20 DTAG 67 NKSD 126 VETSAKT 153
# P11233 GSGGVGK 20 DTAG 67 NKSD 126 AKTRANV 157
# P18613 GSGGVGK 11 DTAG 58 NKCD 117 YFLEASA 143
# P18613 GSGGVGK 11 DTAG 58 NKCD 117 LEASAKN 145
# P62836 GSGGVGK 9 DTAG 56 NKCD 115 FLESSAK 142
# P62836 GSGGVGK 9 DTAG 56 NKCD 115 LESSAKS 143
# P62836 GSGGVGK 9 DTAG 56 NKCD 115 SAKSKIN 146
# P0CY32 GGGGVGK 10 DTAG 57 NKCD 116 LETSAKQ 143
# P01111 GAGGVGK 9 DTAG 56 NKCD 115 IETSAKT 141
# P01111 GAGGVGK 9 DTAG 56 NKCD 115 GVEDAFY 150
# Q295X7 GAGGVGK 9 DTAG 56 NKCD 115 IETSAKT 141
# Q295X7 GAGGVGK 9 DTAG 56 NKCD 115 GVDDAFY 150
# P08644 GAGGVGK 9 DTAG 56 NKCD 115 IETSAKT 141
# P08644 GAGGVGK 9 DTAG 56 NKCD 115 RVEDAFY 150
# P62833 GSGGVGK 9 DTAG 56 NKCD 115 FLESSAK 142
# P62833 GSGGVGK 9 DTAG 56 NKCD 115 LESSAKS 143
# P62833 GSGGVGK 9 DTAG 56 NKCD 115 SAKSKIN 146
# Q15382 GYRSVGK 12 DTAG 59 NKKD 118 FLESSAK 144
# Q15382 GYRSVGK 12 DTAG 59 NKKD 118 LESSAKE 145
# Q15382 GYRSVGK 12 DTAG 59 NKKD 118 ENQTAVD 151
# P08645 GSGGVGK 9 DTAG 56 NKCD 115 METSAKA 142
# P08645 GSGGVGK 9 DTAG 56 NKCD 115 TSAKAKV 144
# P32252 GGGGVGK 12 DTAG 59 NKCD 118 LETSAKK 145
# O42277 GAGGVGK 9 DTAG 56 NKCD 115 IETSAKT 141
# O42277 GAGGVGK 9 DTAG 56 NKCD 115 GVDDAFY 150
# Q9YH38 GAGGVGK 9 DTAG 56 NKCD 115 IETSAKT 141
# Q9YH38 GAGGVGK 9 DTAG 56 NKCD 115 GVDDAFY 150
# P28775 GGGGVGK 16 DTAG 63 NKCD 122 VETSAKV 149
# P28775 GQEEYGA 66 DQDT 111 NKEQ 174 NDEGAGG 202
# P28775 GQEEYGA 66 DTFP 113 NKEQ 174 NDEGAGG 202
# P48555 GSGGVGK 17 DTAG 64 NKCD 123 VETSAKT 150
# P36860 GSGGVGK 20 DTAG 67 NKSD 127 VETSAKT 154
GAGGVGK 9 DTAG 56 NKCD 115 GVEDAFY 150
# P61226 GSGGVGK 9 DTAG 56 NKVD 115 METSAKN 142
# P61226 GSGGVGK 9 DTAG 56 NKVD 115 AKNKASV 146
# P61226 GSGGVGK 9 DTAG 56 NKVD 115 NKASVDE 148
# Q92963 GAGGVGK 27 DTAG 74 NKSD 133 FETSAAY 160
# Q92963 GAGGVGK 27 DTAG 74 NKSD 133 ETSAAYR 161
# Q99578 GAGGVGK 26 DTAG 73 NKID 132 FETSAAL 159
# Q99578 GAGGVGK 26 DTAG 73 NKID 132 ETSAALR 160
# P63321 GSGGVGK 20 DTAG 67 NKSD 126 VETSAKT 153
# P63321 GSGGVGK 20 DTAG 67 NKSD 126 AKTRANV 157
# O93856 GGGGEGK 14 DTAG 61 NKCD 120 IETSAKS 147
# O93856 GGGGEGK 14 DTAG 61 NKCD 120 SAKSRIN 150
# P63320 GSGGVGK 20 DTAG 67 NKSD 126 VETSAKT 153
# P63320 GSGGVGK 20 DTAG 67 NKSD 126 AKTRANV 157
# Q9YH09 GSGGVGK 20 DTAG 67 NKSD 127 VETSAKT 154
# Q9YH09 GSGGVGK 20 DTAG 67 NKSD 127 AKTRANV 158
# Q86L51 GAGSVGK 28 DTAG 75 NKID 134 DFWEASS 160
# Q86L51 GAGSVGK 28 DTAG 75 NKID 134 WEASSKD 162
# Q86L51 GAGSVGK 28 DTAG 75 NKID 134 EASSKDR 163
# Q04970 GAGGVGK 9 DTAG 56 NKCD 115 IETSAKT 141
# Q04970 GAGGVGK 9 DTAG 56 NKCD 115 GVEDAFY 150
# Q06AU2 GSGGVGK 9 DTAG 56 NKVD 115 METSAKN 142
# Q06AU2 GSGGVGK 9 DTAG 56 NKVD 115 AKNKASV 146
# Q06AU2 GSGGVGK 9 DTAG 56 NKVD 115 NKASVDE 148
# Q9NYN1 GRRGAGK 26 DTAD 73 NKLD 133 FEVSACL 160
# Q9NYN1 GRRGAGK 26 DLDT 76 NKLD 133 FEVSACL 160
# P51539 GAGGVGK 15 DTAG 62 NKVD 121 VETSAKT 147
# P51539 GAGGVGK 15 DTAG 62 NKVD 121 GVEEAFF 156
# P51539 GAGGVGK 15 DTAG 62 PKRD 126 GVEEAFF 156
# P10114 GSGGVGK 9 DTAG 56 NKVD 115 METSAKS 142
# P10114 GSGGVGK 9 DTAG 56 NKVD 115 SAKSKTM 145
# Q94694 GSGGVGK 11 DTAG 58 NKCD 117 AFLEASA 143
# Q94694 GSGGVGK 11 DTAG 58 NKCD 117 LEASAKN 145
# P32254 GPGGVGK 9 DTAG 56 NKCD 115 LETSAKE 142
# P32254 GPGGVGK 9 DTAG 56 NKCD 115 INVSESF 150
# P22278 GGGGVGK 16 DTAG 63 NKCD 122 IETSAKQ 149
# B4PUP5 GAGGVGK 9 DTAG 56 NKCD 115 IETSAKT 141
# B4PUP5 GAGGVGK 9 DTAG 56 NKCD 115 GVDDAFY 150
# P22280 GGGGVGK 15 DTAG 62 NKCD 121 SETSAKQ 148
# Q55CB9 GDGGVGK 39 DTAG 86 NKSD 145 MEVSAKN 172
# Q55CB9 GDGGVGK 39 DTAG 86 NKSD 145 KNRSNID 177
# P0CQ42 GGGGVGK 15 DTAG 62 NKCD 121 IETSAKQ 148
# Q2MJK3 GAGGVGK 9 DTAG 56 NKCD 115 IETSAKT 141
# Q2MJK3 GAGGVGK 9 DTAG 56 NKCD 115 GVEDAFY 150
# P83831 GAGGVGK 9 DTAG 56 NKCD 115 IETSAKT 141
# P83831 GAGGVGK 9 DTAG 56 NKCD 115 GVDDAFY 150
# Q12526 GGGGVGK 14 DTAG 61 NKCD 120 IETSAKS 147
# Q12526 GGGGVGK 14 DTAG 61 NKCD 120 SAKSRIN 150
# P01115 GARGVGK 61 DTTG 108 NKCD 167 IETSAKT 193
# P01115 GARGVGK 61 DTTG 108 NKCD 167 GVEDAFY 202
# Q9VND8 GYRSVGK 11 DTAG 58 NKID 117 LETSAKQ 144
# Q9VND8 GYRSVGK 11 DTAG 58 NKID 117 QNESVGD 150
# Q921J2 GYRSVGK 12 DTAG 59 NKKD 118 FLESSAK 144
# Q921J2 GYRSVGK 12 DTAG 59 NKKD 118 LESSAKE 145
# Q921J2 GYRSVGK 12 DTAG 59 NKKD 118 ENQTAVD 151
# P97538 GDGGVGK 19 DTAG 66 NKVD 125 IETSAKD 152
# Q7ZXH7 GSGGVGK 9 DTAG 56 NKCD 115 FLESSAK 142
# Q5E9J3 GASGVGK 39 DTPG 86 NKAD 151 YEVSVSE 178
# Q5E9J3 GASGVGK 39 DTPG 86 NKAD 151 VSVSEND 180
# P55040 GEQGVGK 81 DMWE 130 NKSD 190 IETSAAV 217
# P55040 GEQGVGK 81 DMWE 130 NKSD 190 ETSAAVQ 218
# P22981 GDGGVGK 9 DTAG 56 NKCD 115 VDTSAKT 141
# P22981 GDGGVGK 9 DTAG 56 NKCD 115 GVDEAFY 150
# Q54BW4 DSSTIGK 2546 YISG 2596 NVGD 2659 VEPGADT 2691
# Q54BW4 WLQKEGK 3766 DSET 3815 NQRD 3873 LIPSACI 3906
# Q54BW4 WLQKEGK 3766 SETG 3816 NQRD 3873 LIPSACI 3906
# Q54BW4 QKEGKGK 3768 DSET 3815 NQRD 3873 LIPSACI 3906
# Q54BW4 QKEGKGK 3768 SETG 3816 NQRD 3873 LIPSACI 3906
# Q6IMA7 GASGVGK 38 DTPG 85 NKAD 150 YEVSVSE 177
# Q6IMA7 GASGVGK 38 DTPG 85 NKAD 150 VSVSENY 179
# Q5FVY2 GGSGVGK 39 DTPG 86 NKAD 151 YEVSVSE 178
# Q5FVY2 GGSGVGK 39 DTPG 86 NKAD 151 VSVSENY 180
# P13856 GAGGVGK 9 DTAG 56 NKAD 115 YETSALL 143
# P13856 GAGGVGK 9 DTAG 56 NKAD 115 LLRSNVD 148
# P52498 GAGGVGK 9 DTAG 56 NKCD 115 YETSAMY 143
# Q6IMB1 GAGCVGK 33 TPGG 81 NKGD 146 LEISTSE 173
# Q6IMB1 GAGCVGK 33 TPGG 81 NKGD 146 ISTSENY 175
# Q8AVS6 GGSGVGK 40 DTPG 87 NKAD 152 YEVSVSE 179
# Q8AVS6 GGSGVGK 40 DTPG 87 NKAD 152 VSVSENY 181
# Q9BPW5 GASGVGK 39 DTPG 86 NKAD 151 YEVSVSE 178
# Q9BPW5 GASGVGK 39 DTPG 86 NKAD 151 VSVSENY 180
# Roc
# Arf
# AIG1
# Era
# FeoB
# Hflx
# Hflx
# GB1
# EngB
# EngB
# Dynamin
# Dynamin
# IRG
# Obg
# Obg
# Septin
# SRP
# Translational
# Translational
# Translational
# Translational
# tRme
# EngA

# %%
gdomains = pd.DataFrame(abc, columns=['ProteinID', 'G1-box', 'Position', 'G3-box', 'Position', 'G4-box', 'Position', 'G5-box', 'Position'])
gdomains= gdomains[gdomains['ProteinID'].astype(bool)]

# %%
gdomains.head()
# Out:
#   ProteinID   G1-box Position G3-box  ...  G4-box Position   G5-box Position
# 0    P01116  GAGGVGK        9   DTAG  ...    NKCD      115  IETSAKT      141
# 1    P01116  GAGGVGK        9   DTAG  ...    NKCD      115  RVEDAFY      150
# 2    P32253  GDGGVGK       10   DTAG  ...    NKAD      116  LETSAKS      144
# 3    P32253  GDGGVGK       10   DTAG  ...    NKAD      116  SAKSRVN      147
# 4    P32883  GAGGVGK        9   DTAG  ...    NKCD      115  IETSAKT      141
#
# [5 rows x 9 columns]

# %%
gdomains.to_csv(outpath, sep=',', encoding='utf-8', index = False)
