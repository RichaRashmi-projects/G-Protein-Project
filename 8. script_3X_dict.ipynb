# %%
# !pip install pandas
# !pip install python-Levenshtein
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (0.25.3)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas) (2.6.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from pandas) (1.17.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas) (1.12.0)
# Requirement already satisfied: python-Levenshtein in /usr/local/lib/python3.6/dist-packages (0.12.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from python-Levenshtein) (42.0.2)

# %%
#import required libraries
import pandas as pd
import Levenshtein
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# funtion to get all the possible 7mers with one 3X in it.

# %%
def list_of_7mer_3X(sevenmer):
    x_data = []
    for r1 in range(7):
        for r2 in range(7):
            for r3 in range(7):
                if (r1!=r2 and r1!=r3 and r2!=r3):
                    x=list(sevenmer)
                    x[r1]="X"
                    x[r2]="X"
                    x[r3]="X"
                    x= ''.join(x)
                    x_data.append(x)
    return x_data

# %% [markdown]
# Enter path to the 7mer master sheet which contains paths for input and output.

# %%
sheet_path= "/content/drive/My Drive/Colab Notebooks/GProtein_Project/7mer_sheet.csv"
data_sheet = pd.read_csv(sheet_path)

# %%
data_sheet.head()
# Out:
#   Protein_Class  ...                                   Outpath_4X_count
# 0           Rab  ...  /content/drive/My Drive/Colab Notebooks/GProte...
# 1           Rac  ...  /content/drive/My Drive/Colab Notebooks/GProte...
# 2           Ran  ...  /content/drive/My Drive/Colab Notebooks/GProte...
# 3           Ras  ...  /content/drive/My Drive/Colab Notebooks/GProte...
# 4           Roc  ...  /content/drive/My Drive/Colab Notebooks/GProte...
#
# [5 rows x 37 columns]

# %% [markdown]
# Enter the name of the family you for which you want to introduce 3X in the G5-Box 7mers.

# %%
family = input("Enter Protein Family: ")
print (family)
# Out:
# Enter Protein Family: Ras
# Ras

# %% [markdown]
# Insert 3X at all possible positions in G5-Box from 'SA' with 1 mismatch G-Domains

# %%
for x in range(20):
    protein_family = data_sheet.loc[x , "Protein_Class"]
    print (protein_family)
    if (family==protein_family):
        print (protein_family)
        inpath_SA_mm= data_sheet.loc[x , "Inpath_SA_mm"]
        outpath1_SA_mm= data_sheet.loc[x , "Outpath_3X_SA_mm"]
        outpath2_SA_mm= data_sheet.loc[x , "Outpath_3X_SA_mm_count"]

        total= data_sheet.loc[x , "Count"]

        data = pd.read_csv(inpath_SA_mm)

        unique_7mers= data['G5-box'].unique()
        temp= data

        id_set = {}

        for j in range(temp.shape[0]):
            seq= temp.loc[j,"G5-box"]
            ID= temp.loc[j,"ProteinID"]
            
            x_data = list_of_7mer_3X(seq)
            for x in x_data:
                if(x not in id_set):
                    id_set[x] = set()
                    id_set[x].add(ID)
                else:
                    id_set[x].add(ID)

# %%
id_set.items()
# Out:
# dict_items([('XXXSAKT', {'O42277', 'Q95ME4', 'P51539', 'Q55CB7', 'P08556', 'P79800', 'Q9YH09', 'P22124', 'Q9JIW9', 'Q55CB8', 'B3NZR4', 'P01117', 'P12825', 'P23175', 'B4GFJ8', 'Q5F352', 'Q04970', 'Q07983', 'P32883', 'Q05147', 'Q5EFX7', 'P22981', 'P01116', 'B3M185', 'P83832', 'P63320', 'P01115', 'P01111', 'P36860', 'P08642', 'P01113', 'B4NJ72', 'Q9YH38', 'P63321', 'P11234', 'P83831', 'P08646', 'P48555', 'P08644', 'P11233', 'B4LY29', 'Q5R4B8', 'Q295X7', 'B4PUP5', 'O95661', 'Q2MJK3', 'Q5RD87', 'B4JFU8', 'P05774', 'P63322', 'B4HKC7', 'Q7TN89', 'Q91806', 'P01114', 'Q7Z444', 'P22126'}), ('XXTXAKT', {'O42277', 'Q95ME4', 'P51539', 'P08556', 'P79800', 'Q9YH09', 'P22124', 'Q9JIW9', 'B3NZR4', 'P01117', 'P12825', 'P23175', 'B4GFJ8', 'Q5F352', 'Q04970', 'Q07983', 'P32883', 'Q05147', 'Q5EFX7', 'P22981', 'P01116', 'B3M185', 'P83832', 'P63320', 'P01115', 'P01111', 'P36860', 'P08642', 'P01113', 'B4NJ72', 'Q9YH38', 'P63321', 'P11234', 'P83831', 'P08646', 'P48555', 'P08644', 'P11233', 'B4LY29', 'Q5R4B8', 'Q295X7', 'B4PUP5', 'Q2MJK3', 'Q5RD87', 'B4JFU8', 'P05774', 'P63322', 'B4HKC7', 'Q7TN89', 'Q91806', 'P01114', 'Q7Z444', 'P22126'}), ('XXTSXKT', {'O42277', 'Q95ME4', 'P51539', 'P08556', 'P79800', 'Q9YH09', 'P22124', 'Q9JIW9', 'B3NZR4', 'P01117', 'P12825', 'P23175', 'B4GFJ8', 'Q5F352', 'Q04970', 'Q07983', 'P32883', 'Q05147', 'Q5EFX7', 'P22981', 'P01116', 'B3M185', 'P83832', 'P63320', 'P01115', 'P01111', 'P36860', 'P08642', 'P01113', 'B4NJ72', 'Q9YH38', 'P63321', 'P11234', 'P83831', 'P08646', 'P48555', 'P08644', 'P11233', 'B4LY29', 'Q5R4B8', 'Q295X7', 'B4PUP5', 'Q2MJK3', 'Q5RD87', 'B4JFU8', 'P05774', 'P63322', 'B4HKC7', 'Q7TN89', 'Q91806', 'P01114', 'Q7Z444', 'P22126'}), ('XXTSAXT', {'O42277', 'Q95ME4', 'P51539', 'P08556', 'P79800', 'Q9YH09', 'P22124', 'Q9JIW9', 'B3NZR4', 'P01117', 'P12825', 'P23175', 'B4GFJ8', 'Q5F352', 'Q04970', 'Q07983', 'P32883', 'Q05147', 'Q5EFX7', 'P22981', 'P01116', 'B3M185', 'P83832', 'P63320', 'P01115', 'P01111', 'P36860', 'P08642', 'P01113', 'B4NJ72', 'Q9YH38', 'P63321', 'P11234', 'P83831', 'P08646', 'P48555', 'P08644', 'P11233', 'B4LY29', 'Q5R4B8', 'Q295X7', 'B4PUP5', 'Q2MJK3', 'Q5RD87', 'B4JFU8', 'P05774', 'P63322', 'B4HKC7', 'Q7TN89', 'Q91806', 'P01114', 'Q7Z444', 'P22126'}), ('XXTSAKX', {'P28775', 'Q12526', 'P79800', 'Q9JIW9', 'Q9Y3L5', 'Q80ZJ1', 'P01119', 'P23175', 'P97538', 'Q07983', 'A8NU18', 'P01116', 'P61226', 'B3M185', 'P63320', 'Q55BW0', 'P01111', 'O93856', 'Q8BU31', 'P22280', 'P0CQ43', 'C4YKT4', 'P15064', 'P34729', 'Q9YH09', 'O08989', 'P61227', 'Q08DI5', 'P22981', 'P08645', 'Q5R988', 'P01115', 'P08642', 'P01113', 'Q9YH38', 'Q09930', 'P11234', 'P11233', 'Q96HU8', 'Q2MJK3', 'B4HKC7', 'P05774', 'O42785', 'P01114', 'Q7Z444', 'P32252', 'O42277', 'P08556', 'Q18246', 'P01117', 'P12825', 'P32883', 'P01120', 'Q05058', 'P36860', 'P32253', 'Q5R4B8', 'P0CQ42', 'Q5RD87', 'B4JFU8', 'P63322', 'Q91806', 'P22126', 'P10114', 'Q5R6S2', 'Q95ME4', 'P51539', 'P08647', 'P22278', 'P61225', 'P22124', 'B3NZR4', 'Q06AU2', 'B4GFJ8', 'O14807', 'P0CY32', 'Q5F352', 'Q04970', 'Q05147', 'Q5EFX7', 'P34726', 'P87018', 'P83832', 'P32254', 'B4NJ72', 'P63321', 'P83831', 'P08646', 'P48555', 'P08644', 'B4LY29', 'B4PUP5', 'Q295X7', 'Q9VND8', 'Q7TN89', 'Q59XU5', 'O95057'}), ('XEXXAKT', {'O42277', 'Q95ME4', 'P51539', 'Q55CB7', 'P08556', 'P79800', 'Q9YH09', 'P22124', 'Q9JIW9', 'Q55CB8', 'B3NZR4', 'P01117', 'P12825', 'P23175', 'B4GFJ8', 'Q5F352', 'Q04970', 'Q07983', 'P32883', 'Q05147', 'Q5EFX7', 'P01116', 'B3M185', 'P83832', 'P63320', 'P01115', 'P01111', 'P36860', 'P08642', 'B4NJ72', 'Q9YH38', 'P63321', 'P11234', 'P83831', 'P08646', 'P48555', 'P08644', 'P11233', 'B4LY29', 'Q5R4B8', 'Q295X7', 'B4PUP5', 'O95661', 'Q2MJK3', 'Q5RD87', 'B4JFU8', 'P05774', 'P63322', 'B4HKC7', 'Q91806', 'P01114', 'Q7Z444', 'P22126'}), ('XEXSXKT', {'O42277', 'Q95ME4', 'P51539', 'Q55CB7', 'P08556', 'P79800', 'Q9YH09', 'P22124', 'Q9JIW9', 'Q55CB8', 'B3NZR4', 'P01117', 'P12825', 'P23175', 'B4GFJ8', 'Q5F352', 'Q04970', 'Q07983', 'P32883', 'Q05147', 'Q5EFX7', 'P01116', 'B3M185', 'P838 ...

# %% [markdown]
# Write the results to the drive.

# %%
with open(outpath1_SA_mm, 'w') as f:   
    [f.write('{0},{1}\n'.format(key, value)) for key, value in id_set.items()]

with open(outpath2_SA_mm, 'w') as f:
    [f.write('{0},{1}\n'.format(key, [len(value),round((100 * len(value) / total),2)])) for key, value in id_set.items()]

# %% [markdown]
# Insert 3X at all possible positions in G5-Box from 'A' with no mismatch G-Domains

# %%
for x in range(20):
    protein_family = data_sheet.loc[x , "Protein_Class"]
    print (protein_family)
    if (family==protein_family):
        print (protein_family)
        inpath_A_nomm= data_sheet.loc[x , "Inpath_A_nomm"]
        outpath1_A_nomm= data_sheet.loc[x , "Outpath_3X_A_nomm"]
        outpath2_A_nomm= data_sheet.loc[x , "Outpath_3X_A_nomm_count"]

        total= data_sheet.loc[x , "Count"]

        data = pd.read_csv(inpath_A_nomm)

        unique_7mers= data['G5-box'].unique()
        temp= data

        id_set1 = {}

        for j in range(temp.shape[0]):
            seq= temp.loc[j,"G5-box"]
            ID= temp.loc[j,"ProteinID"]
            
            x_data = list_of_7mer_3X(seq)
            for x in x_data:
                if(x not in id_set1):
                    id_set1[x] = set()
                    id_set1[x].add(ID)
                else:
                    id_set1[x].add(ID)
# Out:
# Rab
# Rac
# Ran
# Ras
# Ras
# Roc
# Arf
# AIG1
# Era
# FeoB
# Hflx
# GB1
# EngB
# Dynamin
# IRG
# Obg
# Septin
# SRP
# Translational
# tRme
# EngA

# %%
id_set1.items()
# Out:
# dict_items([('XXXAKTR', {'O42277', 'Q95ME4', 'Q55CB7', 'P08556', 'P79800', 'Q9YH09', 'P22124', 'Q9JIW9', 'Q55CB8', 'B3NZR4', 'P01117', 'P12825', 'P23175', 'B4GFJ8', 'Q5F352', 'Q04970', 'Q07983', 'P32883', 'Q05147', 'Q5EFX7', 'P22981', 'P01116', 'B3M185', 'P83832', 'P63320', 'P01115', 'P01111', 'P36860', 'P08642', 'P01113', 'B4NJ72', 'Q9YH38', 'P63321', 'P11234', 'P83831', 'P08646', 'P48555', 'P08644', 'P11233', 'B4LY29', 'Q5R4B8', 'Q295X7', 'B4PUP5', 'Q2MJK3', 'Q5RD87', 'B4JFU8', 'P05774', 'P63322', 'B4HKC7', 'Q7TN89', 'Q91806', 'P01114', 'Q7Z444'}), ('XXSXKTR', {'O42277', 'Q95ME4', 'Q55CB7', 'P08556', 'P79800', 'Q9YH09', 'P22124', 'Q9JIW9', 'Q55CB8', 'B3NZR4', 'P01117', 'P12825', 'P23175', 'B4GFJ8', 'Q5F352', 'Q04970', 'Q07983', 'P32883', 'Q05147', 'Q5EFX7', 'P22981', 'P01116', 'B3M185', 'P83832', 'P63320', 'P01115', 'P01111', 'P36860', 'P08642', 'P01113', 'B4NJ72', 'Q9YH38', 'P63321', 'P11234', 'P83831', 'P08646', 'P48555', 'P08644', 'P11233', 'B4LY29', 'Q5R4B8', 'Q295X7', 'B4PUP5', 'Q2MJK3', 'Q5RD87', 'B4JFU8', 'P05774', 'P63322', 'B4HKC7', 'Q7TN89', 'Q91806', 'P01114', 'Q7Z444'}), ('XXSAXTR', {'O42277', 'Q95ME4', 'Q55CB7', 'P08556', 'P79800', 'Q9YH09', 'P22124', 'Q9JIW9', 'Q55CB8', 'B3NZR4', 'P01117', 'P12825', 'P23175', 'B4GFJ8', 'Q5F352', 'Q04970', 'Q07983', 'P32883', 'Q05147', 'Q5EFX7', 'P22981', 'P01116', 'B3M185', 'P83832', 'P63320', 'P01115', 'P01111', 'P36860', 'P08642', 'P01113', 'B4NJ72', 'Q9YH38', 'P63321', 'P11234', 'P83831', 'P08646', 'P48555', 'P08644', 'P11233', 'B4LY29', 'Q5R4B8', 'Q295X7', 'B4PUP5', 'Q2MJK3', 'Q5RD87', 'B4JFU8', 'P05774', 'P63322', 'B4HKC7', 'Q7TN89', 'Q91806', 'P01114', 'Q7Z444'}), ('XXSAKXR', {'Q55CC0', 'P62071', 'P32252', 'O42277', 'Q95ME4', 'P28775', 'P08647', 'Q55CB7', 'Q12526', 'P08556', 'P79800', 'Q9YH09', 'P22124', 'P22278', 'Q55CB8', 'Q9JIW9', 'B3NZR4', 'P01117', 'P12825', 'P23175', 'B4GFJ8', 'Q5F352', 'P0CY32', 'Q07983', 'Q04970', 'A8NU18', 'P32883', 'Q05147', 'Q5EFX7', 'P22981', 'Q55CB9', 'P01116', 'P38976', 'P87018', 'P34726', 'P15064', 'B3M185', 'P10833', 'P83832', 'P63320', 'Q05058', 'P01115', 'P32254', 'P01111', 'O93856', 'P36860', 'P08642', 'P01113', 'B4NJ72', 'Q9YH38', 'P32253', 'P11234', 'P63321', 'P08646', 'P83831', 'P48555', 'P08644', 'P11233', 'B4LY29', 'Q5R4B8', 'Q295X7', 'B4PUP5', 'P03967', 'Q2MJK3', 'P0CQ42', 'Q5RD87', 'B4JFU8', 'P05774', 'P22280', 'P63322', 'B4HKC7', 'Q7TN89', 'O42785', 'Q91806', 'P01114', 'P10301', 'Q7Z444', 'P0CQ43', 'Q55CA9', 'P04388', 'Q59XU5', 'C4YKT4', 'P62070', 'P34729'}), ('XXSAKTX', {'O42277', 'Q95ME4', 'P51539', 'Q55CB7', 'P08556', 'P79800', 'Q9YH09', 'P22124', 'Q9JIW9', 'Q55CB8', 'B3NZR4', 'P01117', 'P12825', 'P23175', 'B4GFJ8', 'Q5F352', 'Q04970', 'Q07983', 'P32883', 'Q05147', 'Q5EFX7', 'P22981', 'P01116', 'B3M185', 'P83832', 'P63320', 'P01115', 'P01111', 'P36860', 'P08642', 'P01113', 'B4NJ72', 'Q9YH38', 'P63321', 'P11234', 'P83831', 'P08646', 'P48555', 'P08644', 'P11233', 'B4LY29', 'Q5R4B8', 'Q295X7', 'B4PUP5', 'O95661', 'Q2MJK3', 'Q5RD87', 'B4JFU8', 'P05774', 'P63322', 'B4HKC7', 'Q7TN89', 'Q91806', 'P01114', 'Q7Z444', 'P22126'}), ('XTXXKTR', {'O42277', 'Q95ME4', 'P08556', 'P79800', 'Q9YH09', 'P22124', 'Q9JIW9', 'B3NZR4', 'P01117', 'P12825', 'P23175', 'B4GFJ8', 'Q5F352', 'Q04970', 'Q07983', 'P32883', 'Q05147', 'Q5EFX7', 'P22981', 'P01116', 'B3M185', 'P83832', 'P63320', 'P01115', 'P01111', 'P36860', 'P08642', 'P01113', 'B4NJ72', 'Q9YH38', 'P63321', 'P11234', 'P83831', 'P08646', 'P48555', 'P08644', 'P11233', 'B4LY29', 'Q5R4B8', 'Q295X7', 'B4PUP5', 'Q2MJK3', 'Q5RD87', 'B4JFU8', 'P05774', 'P63322', 'B4HKC7', 'Q7TN89', 'Q91806', 'P01114', 'Q7Z444'}), ('XTXAXTR', {'O42277', 'Q95ME4', 'P08556', 'P79800', 'Q9YH09', 'P22124', 'Q9JIW9', 'B3NZR4', 'P01117', 'P12825', 'P23175', 'B4GFJ8', 'Q5F352', 'Q04970', 'Q07983', 'P32883', 'Q05147', 'Q5EFX7', 'P22981', 'P01116', 'B3M185', 'P83832', 'P63320', 'P01115', 'P01111', 'P36860', 'P08642', 'P01113', 'B4NJ72', 'Q9YH38', 'P63321', 'P11234', 'P83831', 'P08646', 'P48555', 'P08644', 'P11233', 'B4LY29', 'Q5R4 ...

# %% [markdown]
# Write the results to the drive.

# %%
with open(outpath1_A_nomm, 'w') as f:   
    [f.write('{0},{1}\n'.format(key, value)) for key, value in id_set1.items()]

with open(outpath2_A_nomm, 'w') as f:
    [f.write('{0},{1}\n'.format(key, [len(value),round((100 * len(value) / total),2)])) for key, value in id_set1.items()]

# %% [markdown]
# Insert 3X at all possible positions in G5-Box from 'SA' with no mismatch G-Domains

# %%
for x in range(20):
    protein_family = data_sheet.loc[x , "Protein_Class"]
    print (protein_family)
    if (family==protein_family):
        print (protein_family)
        inpath_SA_nomm= data_sheet.loc[x , "Inpath_SA_nomm"]
        outpath1_SA_nomm= data_sheet.loc[x , "Outpath_3X_SA_nomm"]
        outpath2_SA_nomm= data_sheet.loc[x , "Outpath_3X_SA_nomm_count"]

        total= data_sheet.loc[x , "Count"]

        data = pd.read_csv(inpath_SA_nomm)

        unique_7mers= data['G5-box'].unique()
        temp= data

        id_set2 = {}

        for j in range(temp.shape[0]):
            seq= temp.loc[j,"G5-box"]
            ID= temp.loc[j,"ProteinID"]
            
            x_data = list_of_7mer_3X(seq)
            for x in x_data:
                if(x not in id_set2):
                    id_set2[x] = set()
                    id_set2[x].add(ID)
                else:
                    id_set2[x].add(ID)
# Out:
# Rab
# Rac
# Ran
# Ras
# Ras
# Roc
# Arf
# AIG1
# Era
# FeoB
# Hflx
# GB1
# EngB
# Dynamin
# IRG
# Obg
# Septin
# SRP
# Translational
# tRme
# EngA

# %%
id_set2.items()

# %% [markdown]
# Write the results to the drive.

# %%
with open(outpath1_SA_nomm, 'w') as f:   
    [f.write('{0},{1}\n'.format(key, value)) for key, value in id_set2.items()]

with open(outpath2_SA_nomm, 'w') as f:
    [f.write('{0},{1}\n'.format(key, [len(value),round((100 * len(value) / total),2)])) for key, value in id_set2.items()]

# %% [markdown]
# Insert 3X at all possible positions in combined G5-Boxes from 'A' with no mismatch , 'SA' with no mismatch and 'SA' with one mismatch G-Domains

# %%
for x in range(20):
    protein_family = data_sheet.loc[x , "Protein_Class"]
    print (protein_family)
    if (family==protein_family):
        print (protein_family)
        inpath_SA_nomm= data_sheet.loc[x , "Inpath_SA_nomm"]
        inpath_SA_mm= data_sheet.loc[x , "Inpath_SA_mm"]
        inpath_A_nomm= data_sheet.loc[x , "Inpath_A_nomm"]
        
        outpath1 = data_sheet.loc[x , "Outpath_3X"]
        outpath2 = data_sheet.loc[x , "Outpath_3X_count"]


        SA_nomm= pd.read_csv(inpath_SA_nomm)
        A_nomm= pd.read_csv(inpath_A_nomm)
        SA_mm= pd.read_csv(inpath_SA_mm)

        table= [SA_nomm[['ProteinID', 'G5-box', 'Position']], A_nomm[['ProteinID', 'G5-box', 'Position']], SA_mm[['ProteinID', 'G5-box', 'Position']]]

        #table= [A_nomm[['Entry', 'G5_box', 'Value']], SA_mm[['Entry', 'G5_box', 'Value']]]


        data= pd.concat(table)
        data= data.reset_index(drop=True)
        
        unique_7mers= data['G5-box'].unique()
        temp= data

        id_set3 = {}

        for j in range(temp.shape[0]):
            seq= temp.loc[j,"G5-box"]
            ID= temp.loc[j,"ProteinID"]
            
            x_data = list_of_7mer_3X(seq)
            for x in x_data:
                if(x not in id_set3):
                    id_set3[x] = set()
                    id_set3[x].add(ID)
                else:
                    id_set3[x].add(ID)
# Out:
# Rab
# Rac
# Ran
# Ras
# Ras
# Roc
# Arf
# AIG1
# Era
# FeoB
# Hflx
# GB1
# EngB
# Dynamin
# IRG
# Obg
# Septin
# SRP
# Translational
# tRme
# EngA

# %%
id_set3.items()
# Out:
# dict_items([('XXXSAKT', {'O42277', 'Q95ME4', 'P51539', 'Q55CB7', 'P08556', 'P79800', 'Q9YH09', 'P22124', 'Q9JIW9', 'Q55CB8', 'B3NZR4', 'P01117', 'P12825', 'P23175', 'B4GFJ8', 'Q5F352', 'Q04970', 'Q07983', 'P32883', 'Q05147', 'Q5EFX7', 'P22981', 'P01116', 'B3M185', 'P83832', 'P63320', 'P01115', 'P01111', 'P36860', 'P08642', 'P01113', 'B4NJ72', 'Q9YH38', 'P63321', 'P11234', 'P83831', 'P08646', 'P48555', 'P08644', 'P11233', 'B4LY29', 'Q5R4B8', 'Q295X7', 'B4PUP5', 'O95661', 'Q2MJK3', 'Q5RD87', 'B4JFU8', 'P05774', 'P63322', 'B4HKC7', 'Q7TN89', 'Q91806', 'P01114', 'Q7Z444', 'P22126'}), ('XXTXAKT', {'O42277', 'Q95ME4', 'P51539', 'P08556', 'P79800', 'Q9YH09', 'P22124', 'Q9JIW9', 'B3NZR4', 'P01117', 'P12825', 'P23175', 'B4GFJ8', 'Q5F352', 'Q04970', 'Q07983', 'P32883', 'Q05147', 'Q5EFX7', 'P22981', 'P01116', 'B3M185', 'P83832', 'P63320', 'P01115', 'P01111', 'P36860', 'P08642', 'P01113', 'B4NJ72', 'Q9YH38', 'P63321', 'P11234', 'P83831', 'P08646', 'P48555', 'P08644', 'P11233', 'B4LY29', 'Q5R4B8', 'Q295X7', 'B4PUP5', 'Q2MJK3', 'Q5RD87', 'B4JFU8', 'P05774', 'P63322', 'B4HKC7', 'Q7TN89', 'Q91806', 'P01114', 'Q7Z444', 'P22126'}), ('XXTSXKT', {'O42277', 'Q95ME4', 'P51539', 'P08556', 'P79800', 'Q9YH09', 'P22124', 'Q9JIW9', 'B3NZR4', 'P01117', 'P12825', 'P23175', 'B4GFJ8', 'Q5F352', 'Q04970', 'Q07983', 'P32883', 'Q05147', 'Q5EFX7', 'P22981', 'P01116', 'B3M185', 'P83832', 'P63320', 'P01115', 'P01111', 'P36860', 'P08642', 'P01113', 'B4NJ72', 'Q9YH38', 'P63321', 'P11234', 'P83831', 'P08646', 'P48555', 'P08644', 'P11233', 'B4LY29', 'Q5R4B8', 'Q295X7', 'B4PUP5', 'Q2MJK3', 'Q5RD87', 'B4JFU8', 'P05774', 'P63322', 'B4HKC7', 'Q7TN89', 'Q91806', 'P01114', 'Q7Z444', 'P22126'}), ('XXTSAXT', {'O42277', 'Q95ME4', 'P51539', 'P08556', 'P79800', 'Q9YH09', 'P22124', 'Q9JIW9', 'B3NZR4', 'P01117', 'P12825', 'P23175', 'B4GFJ8', 'Q5F352', 'Q04970', 'Q07983', 'P32883', 'Q05147', 'Q5EFX7', 'P22981', 'P01116', 'B3M185', 'P83832', 'P63320', 'P01115', 'P01111', 'P36860', 'P08642', 'P01113', 'B4NJ72', 'Q9YH38', 'P63321', 'P11234', 'P83831', 'P08646', 'P48555', 'P08644', 'P11233', 'B4LY29', 'Q5R4B8', 'Q295X7', 'B4PUP5', 'Q2MJK3', 'Q5RD87', 'B4JFU8', 'P05774', 'P63322', 'B4HKC7', 'Q7TN89', 'Q91806', 'P01114', 'Q7Z444', 'P22126'}), ('XXTSAKX', {'P28775', 'Q12526', 'P79800', 'Q9JIW9', 'Q9Y3L5', 'Q80ZJ1', 'P01119', 'P23175', 'P97538', 'Q07983', 'A8NU18', 'P01116', 'P61226', 'B3M185', 'P63320', 'Q55BW0', 'P01111', 'O93856', 'Q8BU31', 'P22280', 'P0CQ43', 'C4YKT4', 'P15064', 'P34729', 'Q9YH09', 'O08989', 'P61227', 'Q08DI5', 'P22981', 'P08645', 'Q5R988', 'P01115', 'P08642', 'P01113', 'Q9YH38', 'Q09930', 'P11234', 'P11233', 'Q96HU8', 'Q2MJK3', 'B4HKC7', 'P05774', 'O42785', 'P01114', 'Q7Z444', 'P32252', 'O42277', 'P08556', 'Q18246', 'P01117', 'P12825', 'P32883', 'P01120', 'Q05058', 'P36860', 'P32253', 'Q5R4B8', 'P0CQ42', 'Q5RD87', 'B4JFU8', 'P63322', 'Q91806', 'P22126', 'P10114', 'Q5R6S2', 'Q95ME4', 'P51539', 'P08647', 'P22278', 'P61225', 'P22124', 'B3NZR4', 'Q06AU2', 'B4GFJ8', 'O14807', 'P0CY32', 'Q5F352', 'Q04970', 'Q05147', 'Q5EFX7', 'P34726', 'P87018', 'P83832', 'P32254', 'B4NJ72', 'P63321', 'P83831', 'P08646', 'P48555', 'P08644', 'B4LY29', 'B4PUP5', 'Q295X7', 'Q9VND8', 'Q7TN89', 'Q59XU5', 'O95057'}), ('XEXXAKT', {'O42277', 'Q95ME4', 'P51539', 'Q55CB7', 'P08556', 'P79800', 'Q9YH09', 'P22124', 'Q9JIW9', 'Q55CB8', 'B3NZR4', 'P01117', 'P12825', 'P23175', 'B4GFJ8', 'Q5F352', 'Q04970', 'Q07983', 'P32883', 'Q05147', 'Q5EFX7', 'P01116', 'B3M185', 'P83832', 'P63320', 'P01115', 'P01111', 'P36860', 'P08642', 'B4NJ72', 'Q9YH38', 'P63321', 'P11234', 'P83831', 'P08646', 'P48555', 'P08644', 'P11233', 'B4LY29', 'Q5R4B8', 'Q295X7', 'B4PUP5', 'O95661', 'Q2MJK3', 'Q5RD87', 'B4JFU8', 'P05774', 'P63322', 'B4HKC7', 'Q91806', 'P01114', 'Q7Z444', 'P22126'}), ('XEXSXKT', {'O42277', 'Q95ME4', 'P51539', 'Q55CB7', 'P08556', 'P79800', 'Q9YH09', 'P22124', 'Q9JIW9', 'Q55CB8', 'B3NZR4', 'P01117', 'P12825', 'P23175', 'B4GFJ8', 'Q5F352', 'Q04970', 'Q07983', 'P32883', 'Q05147', 'Q5EFX7', 'P01116', 'B3M185', 'P838 ...

# %% [markdown]
# Write the results to the drive.

# %%
with open(outpath1, 'w') as f:   
    [f.write('{0},{1}\n'.format(key, value)) for key, value in id_set3.items()]

with open(outpath2, 'w') as f:
    [f.write('{0},{1}\n'.format(key, [len(value),round((100 * len(value) / total),2)])) for key, value in id_set3.items()]
