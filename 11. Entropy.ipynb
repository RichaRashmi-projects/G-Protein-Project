# %%
import pandas as pd 
import numpy as np
import scipy.stats
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
def calculate_entropy(PWM1, PWM3, PWM4, PWM5):
    
    entropy1 = 0
    entropy3 = 0
    entropy4 = 0
    entropy5 = 0
    
    for i in range(1,PWM1.shape[1]):
        entropy1 += scipy.stats.entropy(PWM1.iloc[:,[(i)]], qk=None, base=None)
        #print (PWM1.iloc[:,[(i)]])
        print (entropy1)
    
    for i in range(1,PWM3.shape[1]):
        entropy3 += scipy.stats.entropy(PWM3.iloc[:,[(i)]], qk=None, base=None)
        #print (PWM3.iloc[:,[(i)]])
        print (entropy3)
        
    for i in range(1,PWM4.shape[1]):
        entropy4 += scipy.stats.entropy(PWM4.iloc[:,[(i)]], qk=None, base=None)
        #print (PWM4.iloc[:,[(i)]])
        print (entropy4)
    
    for i in range(1,PWM5.shape[1]):
        entropy5 += scipy.stats.entropy(PWM5.iloc[:,[(i)]], qk=None, base=None)
        #print (PWM5.iloc[:,[(i)]])
        print (entropy5)    
  
    return np.concatenate((entropy1, entropy3, entropy4, entropy5))

# %%
sheet_path= "/content/drive/My Drive/Colab Notebooks/GProtein_Project/figures/data/Entropy_path.csv"
data = pd.read_csv(sheet_path)

# %%
data.head()
# Out:
#   Protein  ...                                               PWM5
# 0     Rab  ...  /content/drive/My Drive/Colab Notebooks/GProte...
# 1     Rac  ...  /content/drive/My Drive/Colab Notebooks/GProte...
# 2     Ran  ...  /content/drive/My Drive/Colab Notebooks/GProte...
# 3     Ras  ...  /content/drive/My Drive/Colab Notebooks/GProte...
# 4     Roc  ...  /content/drive/My Drive/Colab Notebooks/GProte...
#
# [5 rows x 5 columns]

# %%
family = input("Enter Protein Family: ")
print (family)
# Out:
# Enter Protein Family: Ras
# Ras

# %%
entropy = dict()

# %%
for x in range(data.shape[0]):
    protein_family = data.loc[x , "Protein"]
    print (protein_family)
    if (family==protein_family):
        pwm1= pd.read_csv(data.loc[x , "PWM1"]) 
        pwm3= pd.read_csv(data.loc[x , "PWM3"])
        pwm4= pd.read_csv(data.loc[x , "PWM4"])
        pwm5= pd.read_csv(data.loc[x , "PWM5"])
        
        entropy[family] = calculate_entropy(pwm1, pwm3, pwm4, pwm5)
        print(entropy)
# Out:
# Rab
# Rac
# Ran
# Ras
# [0.03643442]
# [1.72776686]
# [2.80349794]
# [3.24783425]
# [3.51042953]
# [3.51042953]
# [3.51042953]
# [0.34302132]
# [1.05474]
# [2.08154564]
# [2.5482273]
# [0.]
# [0.]
# [1.60956124]
# [1.64599565]
# [0.09996749]
# [1.31924872]
# [1.41921621]
# [1.72288938]
# [2.65940756]
# {'Ras': array([3.51042953, 2.5482273 , 1.64599565, 2.65940756])}
# Roc
# Arf
# AIG1
# Era
# FeoB
# Hflx
# GB1
# EngB
# Dynamin
# IRG
# Obg
# Septin
# SRP
# Translational
# tRme
# EngA

# %%
with open('/content/drive/My Drive/Colab Notebooks/GProtein_Project/figures/data/Entropy.csv', 'w') as f:
    for key in entropy.keys():
        f.write("%s,%s\n"%(key,entropy[key]))
